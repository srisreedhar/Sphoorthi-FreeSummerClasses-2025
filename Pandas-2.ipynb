# %%
import os
import pandas as pd

# %%
pd.set_option('display.max_rows', 500)

# %%
os.getcwd()
# Out:
# 'D:\\SphoorthiFreeClasses\\python'

# %%
url="https://raw.githubusercontent.com/srisreedhar/DataSets/refs/heads/master/animal_sleeptime_ggplot2.csv"

# %%
# reading data and creating a dataframe 
df = pd.read_csv(url)
df
# Out:
#                           name       genus   vore         order  conservation  \
# 0                      Cheetah    Acinonyx  carni     Carnivora            lc
# 1                   Owl monkey       Aotus   omni      Primates           NaN
# 2              Mountain beaver  Aplodontia  herbi      Rodentia            nt
# 3   Greater short-tailed shrew     Blarina   omni  Soricomorpha            lc
# 4                          Cow         Bos  herbi  Artiodactyla  domesticated
# ..                         ...         ...    ...           ...           ...
# 78                  Tree shrew      Tupaia   omni    Scandentia           NaN
# 79        Bottle-nosed dolphin    Tursiops  carni       Cetacea           NaN
# 80                       Genet     Genetta  carni     Carnivora           NaN
# 81                  Arctic fox      Vulpes  carni     Carnivora           NaN
# 82                     Red fox      Vulpes  carni     Carnivora           NaN
#
# ...

# %% [markdown]
# ### Understand the Data

# %%
# shape of data
# coloumn names/rows
# the first and last few rows of the data
# the null values if any in the dataset

# %%
# shape of data
# (rows,columns) 
# m x n
# rows x columns 
df.shape
# Out:
# (83, 11)

# %%
# coloumn names/rows
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83 entries, 0 to 82
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          83 non-null     object
#  1   genus         83 non-null     object
#  2   vore          76 non-null     object
#  3   order         83 non-null     object
#  4   conservation  54 non-null     object
#  5   sleep_total   83 non-null     float64
#  6   sleep_rem     61 non-null     float64
#  7   sleep_cycle   32 non-null     float64
#  8   awake         83 non-null     float64
#  9   brainwt       56 non-null     float64
#  10  bodywt        83 non-null     float64
# dtypes: float64(6), object(5)
# memory usage: 7.3+ KB

# %%
# the first and last few rows of the data
# .head(integer) by default when no arg is given returns first 5 values
# df.head(8)
df.head()
# Out:
#                          name       genus   vore         order  conservation  \
# 0                     Cheetah    Acinonyx  carni     Carnivora            lc
# 1                  Owl monkey       Aotus   omni      Primates           NaN
# 2             Mountain beaver  Aplodontia  herbi      Rodentia            nt
# 3  Greater short-tailed shrew     Blarina   omni  Soricomorpha            lc
# 4                         Cow         Bos  herbi  Artiodactyla  domesticated
#
#    sleep_total  sleep_rem  sleep_cycle  awake  brainwt   bodywt
# 0         12.1        NaN          NaN   11.9      NaN   50.000
# 1         17.0        1.8          NaN    7.0  0.01550    0.480
# 2         14.4        2.4          NaN    9.6      NaN    1.350
# 3         14.9        2.3     0.133333    9.1  0.00029    0.019
# 4          4.0        0.7     0.666667   20.0  0.42300  600.000

# %%
# the first and last few rows of the data
# .tail(integer) by default when no arg is given returns first 5 values
# df.tail(8)
df.tail()
# Out:
#                     name     genus   vore       order conservation  \
# 78            Tree shrew    Tupaia   omni  Scandentia          NaN
# 79  Bottle-nosed dolphin  Tursiops  carni     Cetacea          NaN
# 80                 Genet   Genetta  carni   Carnivora          NaN
# 81            Arctic fox    Vulpes  carni   Carnivora          NaN
# 82               Red fox    Vulpes  carni   Carnivora          NaN
#
#     sleep_total  sleep_rem  sleep_cycle  awake  brainwt   bodywt
# 78          8.9        2.6     0.233333   15.1   0.0025    0.104
# 79          5.2        NaN          NaN   18.8      NaN  173.330
# 80          6.3        1.3          NaN   17.7   0.0175    2.000
# 81         12.5        NaN          NaN   11.5   0.0445    3.380
# 82          9.8        2.4     0.350000   14.2   0.0504    4.230

# %%
# description of the data
# summary statistics / descriptive statistics of the dataset/dataframe
df.describe()
# Out:
#        sleep_total  sleep_rem  sleep_cycle      awake    brainwt       bodywt
# count    83.000000  61.000000    32.000000  83.000000  56.000000    83.000000
# mean     10.433735   1.875410     0.439583  13.567470   0.281581   166.136349
# std       4.450357   1.298288     0.358680   4.452085   0.976414   786.839732
# min       1.900000   0.100000     0.116667   4.100000   0.000140     0.005000
# 25%       7.850000   0.900000     0.183333  10.250000   0.002900     0.174000
# 50%      10.100000   1.500000     0.333333  13.900000   0.012400     1.670000
# 75%      13.750000   2.400000     0.579167  16.150000   0.125500    41.750000
# max      19.900000   6.600000     1.500000  22.100000   5.712000  6654.000000

# %%
# the null values if any in the dataset
df.isnull()
# Out:
#      name  genus   vore  order  conservation  sleep_total  sleep_rem  \
# 0   False  False  False  False         False        False       True
# 1   False  False  False  False          True        False      False
# 2   False  False  False  False         False        False      False
# 3   False  False  False  False         False        False      False
# 4   False  False  False  False         False        False      False
# ..    ...    ...    ...    ...           ...          ...        ...
# 78  False  False  False  False          True        False      False
# 79  False  False  False  False          True        False       True
# 80  False  False  False  False          True        False      False
# 81  False  False  False  False          True        False       True
# 82  False  False  False  False          True        False      False
#
#     sleep_cycle  awake  brainwt  bodywt
# 0          True  False     True   False
# 1          True  False    False   False
# ...

# %%
# df.isnull() returns a dataset with boolean values,
# where ever there is data, the location/cell/value is marked/masked as True and where ever there are null/NA/Nan values
# that is marked as False

# %%
# run an aggregation on .isnull() method to check the count of the null values
df.isnull().sum()
# Out:
# name             0
# genus            0
# vore             7
# order            0
# conservation    29
# sleep_total      0
# sleep_rem       22
# sleep_cycle     51
# awake            0
# brainwt         27
# bodywt           0
# dtype: int64

# %%
# drop rows which has NaN ( not suggeted for small datasets)

# %%
# extracting individual columns from the dataframe/table
# Dataframe.ColumnName
# DataFrame['ColumnName'] 
df.sleep_cycle
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3     0.133333
# 4     0.666667
#         ...
# 78    0.233333
# 79         NaN
# 80         NaN
# 81         NaN
# 82    0.350000
# Name: sleep_cycle, Length: 83, dtype: float64

# %%
df.sleep_rem
# Out:
# 0     NaN
# 1     1.8
# 2     2.4
# 3     2.3
# 4     0.7
#      ...
# 78    2.6
# 79    NaN
# 80    1.3
# 81    NaN
# 82    2.4
# Name: sleep_rem, Length: 83, dtype: float64

# %%
df['name']
# Out:
# 0                        Cheetah
# 1                     Owl monkey
# 2                Mountain beaver
# 3     Greater short-tailed shrew
# 4                            Cow
#                  ...
# 78                    Tree shrew
# 79          Bottle-nosed dolphin
# 80                         Genet
# 81                    Arctic fox
# 82                       Red fox
# Name: name, Length: 83, dtype: object

# %%
sample_dict = {
'sandles':1220,
'idly rava':100,
'jeans':1111,
'fruit':'apple',
'cooldrink':'butter milk'
}
sample_dict
# Out:
# {'sandles': 1220,
#  'idly rava': 100,
#  'jeans': 1111,
#  'fruit': 'apple',
#  'cooldrink': 'butter milk'}

# %%
sample_dict['jeans']
# Out:
# 1111

# %%
# to print all the columns in a dataframe/dataset
# dataFrame.columns
df.columns
# Out:
# Index(['name', 'genus', 'vore', 'order', 'conservation', 'sleep_total',
#        'sleep_rem', 'sleep_cycle', 'awake', 'brainwt', 'bodywt'],
#       dtype='object')

# %%
df[['name','order','genus','sleep_total']]
# Out:
#                           name         order       genus  sleep_total
# 0                      Cheetah     Carnivora    Acinonyx         12.1
# 1                   Owl monkey      Primates       Aotus         17.0
# 2              Mountain beaver      Rodentia  Aplodontia         14.4
# 3   Greater short-tailed shrew  Soricomorpha     Blarina         14.9
# 4                          Cow  Artiodactyla         Bos          4.0
# ..                         ...           ...         ...          ...
# 78                  Tree shrew    Scandentia      Tupaia          8.9
# 79        Bottle-nosed dolphin       Cetacea    Tursiops          5.2
# 80                       Genet     Carnivora     Genetta          6.3
# 81                  Arctic fox     Carnivora      Vulpes         12.5
# 82                     Red fox     Carnivora      Vulpes          9.8
#
# [83 rows x 4 columns]

# %%
# to print multiple columns, we pass the list of columns into DataFrame[List-of-columns]
df[
    ['name','order','sleep_total','bodywt']
]
# Out:
#                               name            order  sleep_total    bodywt
# 0                          Cheetah        Carnivora         12.1    50.000
# 1                       Owl monkey         Primates         17.0     0.480
# 2                  Mountain beaver         Rodentia         14.4     1.350
# 3       Greater short-tailed shrew     Soricomorpha         14.9     0.019
# 4                              Cow     Artiodactyla          4.0   600.000
# 5                 Three-toed sloth           Pilosa         14.4     3.850
# 6                Northern fur seal        Carnivora          8.7    20.490
# 7                     Vesper mouse         Rodentia          7.0     0.045
# 8                              Dog        Carnivora         10.1    14.000
# 9                         Roe deer     Artiodactyla          3.0    14.800
# 10                            Goat     Artiodactyla          5.3    33.500
# ...

# %%
# sorting of values
df.sort_values(by='sleep_total',ascending=False)
# Out:
#                               name          genus     vore            order  \
# 42                Little brown bat         Myotis  insecti       Chiroptera
# 21                   Big brown bat      Eptesicus  insecti       Chiroptera
# 36            Thick-tailed opposum     Lutreolina    carni  Didelphimorphia
# 61                 Giant armadillo     Priodontes  insecti        Cingulata
# 19          North American Opossum      Didelphis     omni  Didelphimorphia
# 17            Long-nosed armadillo        Dasypus    carni        Cingulata
# 1                       Owl monkey          Aotus     omni         Primates
# 69          Arctic ground squirrel   Spermophilus    herbi         Rodentia
# 71  Golden-mantled ground squirrel   Spermophilus    herbi         Rodentia
# 50                           Tiger       Panthera    carni        Carnivora
# 75       Eastern american chipmunk         Tamias    herbi         Rodentia
# ...

# %%
# sort_values(by='sleep_total',ascending=True)
# .sort_values(by=column_name,ascending=True or False)

# %%
# Binning of sleep_total

# %%
# grouping the values and applying the aggregtions on the data
# aggregations - sum, count, min, max 

df.groupby('order')['sleep_total'].mean()
# Out:
# order
# Afrosoricida       15.600000
# Artiodactyla        4.516667
# Carnivora          10.116667
# Cetacea             4.500000
# Chiroptera         19.800000
# Cingulata          17.750000
# Didelphimorphia    18.700000
# Diprotodontia      12.400000
# Erinaceomorpha     10.200000
# Hyracoidea          5.666667
# Lagomorpha          8.400000
# Monotremata         8.600000
# Perissodactyla      3.466667
# Pilosa             14.400000
# Primates           10.500000
# Proboscidea         3.600000
# Rodentia           12.468182
# Scandentia          8.900000
# Soricomorpha       11.100000
# Name: sleep_total, dtype: float64

# %%
df.groupby('order')['sleep_total'].count()
# Out:
# order
# Afrosoricida        1
# Artiodactyla        6
# Carnivora          12
# Cetacea             3
# Chiroptera          2
# Cingulata           2
# Didelphimorphia     2
# Diprotodontia       2
# Erinaceomorpha      2
# Hyracoidea          3
# Lagomorpha          1
# Monotremata         1
# Perissodactyla      3
# Pilosa              1
# Primates           12
# Proboscidea         2
# Rodentia           22
# Scandentia          1
# Soricomorpha        5
# Name: sleep_total, dtype: int64

# %%
df.groupby('order')['sleep_total'].sum()
# Out:
# order
# Afrosoricida        15.6
# Artiodactyla        27.1
# Carnivora          121.4
# Cetacea             13.5
# Chiroptera          39.6
# Cingulata           35.5
# Didelphimorphia     37.4
# Diprotodontia       24.8
# Erinaceomorpha      20.4
# Hyracoidea          17.0
# Lagomorpha           8.4
# Monotremata          8.6
# Perissodactyla      10.4
# Pilosa              14.4
# Primates           126.0
# Proboscidea          7.2
# Rodentia           274.3
# Scandentia           8.9
# Soricomorpha        55.5
# Name: sleep_total, dtype: float64

# %%
# Imbalanced Datasets - Different statistical treatments
